# %% [markdown]
# 1. function movies you might like()
#    1. inside the function open the csv file using read mode
#    2. filter inside the csv file movies by their title
#    3. return a dictionary with the key:movies you might like

# %%
kelvin.shape
# Out:
# (714, 16)

# %%
kelvin.iloc[3,7]
# Out:
# 'the early life and career of vito corleone in 1920s new york city is portrayed, while his son, michael, expands and tightens his grip on the family crime syndicate.'

# %%
kelvin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 714 entries, 0 to 997
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   poster_link    714 non-null    object
#  1   series_title   714 non-null    object
#  2   released_year  714 non-null    object
#  3   certificate    714 non-null    object
#  4   runtime        714 non-null    object
#  5   genre          714 non-null    object
#  6   imdb_rating    714 non-null    float64
#  7   overview       714 non-null    object
#  8   meta_score     714 non-null    float64
#  9   director       714 non-null    object
#  10  star1          714 non-null    object
#  11  star2          714 non-null    object
#  12  star3          714 non-null    object
#  13  star4          714 non-null    object
#  14  no_of_votes    714 non-null    int64
#  15  gross          714 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 111.0+ KB

# %%
# kelvin.columns = [col.lower() for col in kelvin.columns]
kelvin.dropna(inplace=True)
# prin(kelvin['Genre']str.lower())
kelvin.loc[2:1000,['Runtime']]

# kelvin = kelvin.map(lambda x: x.lower() if isinstance(x,str) else x)
# kelvin
# Out:
#      Runtime
# 2    152 min
# 3    202 min
# 4     96 min
# 5    201 min
# 6    154 min
# ..       ...
# 990  157 min
# 991  144 min
# 992   78 min
# 994   87 min
# 997  118 min
#
# [712 rows x 1 columns]

# %%
kelvin.tail()
# Out:
#                                            poster_link           series_title  \
# 990  https://m.media-amazon.com/images/M/MV5BYjRmY2...           Giù la testa
# 991  https://m.media-amazon.com/images/M/MV5BMzAyND...         Kelly's Heroes
# 992  https://m.media-amazon.com/images/M/MV5BMjAwMT...        The Jungle Book
# 994  https://m.media-amazon.com/images/M/MV5BZjQyMG...     A Hard Day's Night
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...  From Here to Eternity
#
#     released_year certificate  runtime                         genre  \
# 990          1971          PG  157 min           Drama, War, Western
# 991          1970          GP  144 min        Adventure, Comedy, War
# 992          1967           U   78 min  Animation, Adventure, Family
# 994          1964           U   87 min        Comedy, Music, Musical
# 997          1953      Passed  118 min           Drama, Romance, War
#
#      imdb_rating                                           overview  \
# ...

# %%
kelvin.sample
# Out:
# <bound method NDFrame.sample of                                            poster_link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 990  https://m.media-amazon.com/images/M/MV5BYjRmY2...
# 991  https://m.media-amazon.com/images/M/MV5BMzAyND...
# 992  https://m.media-amazon.com/images/M/MV5BMjAwMT...
# 994  https://m.media-amazon.com/images/M/MV5BZjQyMG...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
#
#                  series_title released_year certificate  runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
kelvin.describe()
# Out:
#        IMDB_Rating  Meta_score   No_of_Votes
# count   714.000000  714.000000  7.140000e+02
# mean      7.937115   77.158263  3.561348e+05
# std       0.293278   12.401144  3.539011e+05
# min       7.600000   28.000000  2.522900e+04
# 25%       7.700000   70.000000  9.600975e+04
# 50%       7.900000   78.000000  2.366025e+05
# 75%       8.100000   86.000000  5.077922e+05
# max       9.300000  100.000000  2.343110e+06

# %%
import pandas as pd
import csv
# def readcsv():
kelvin=pd.read_csv('imdb_top_1000.csv')
kelvin.dropna(inplace=True)
kelvin.columns=[column.replace(' ','-') for column in kelvin.columns]
skelvin=['Runtime','Genre','Series_Title']
# nkelvin=(nkelvin).lower()
nkelvin=pd.DataFrame(kelvin[skelvin]).copy()
nkelvin = nkelvin.map(lambda x: x.lower() if isinstance(x,str) else x)
nkelvin
# .columns.str.lower()
# Out:
#      Runtime                         Genre              Series_Title
# 0    142 min                         drama  the shawshank redemption
# 1    175 min                  crime, drama             the godfather
# 2    152 min          action, crime, drama           the dark knight
# 3    202 min                  crime, drama    the godfather: part ii
# 4     96 min                  crime, drama              12 angry men
# ..       ...                           ...                       ...
# 990  157 min           drama, war, western              giù la testa
# 991  144 min        adventure, comedy, war            kelly's heroes
# 992   78 min  animation, adventure, family           the jungle book
# 994   87 min        comedy, music, musical        a hard day's night
# 997  118 min           drama, romance, war     from here to eternity
#
# [714 rows x 3 columns]

# %% [markdown]
# data preparation

# %%
kelvin.iloc[0:10]
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/m/mv5bmdfkyt...
# 1  https://m.media-amazon.com/images/m/mv5bm2mynj...
# 2  https://m.media-amazon.com/images/m/mv5bmtmxnt...
# 3  https://m.media-amazon.com/images/m/mv5bmwmwmg...
# 4  https://m.media-amazon.com/images/m/mv5bmwu4n2...
# 5  https://m.media-amazon.com/images/m/mv5bnza5zd...
# 6  https://m.media-amazon.com/images/m/mv5bngnhmd...
# 7  https://m.media-amazon.com/images/m/mv5bnde4ot...
# 8  https://m.media-amazon.com/images/m/mv5bmjaxmz...
# 9  https://m.media-amazon.com/images/m/mv5bmmeznt...
#
#                                     Series_Title Released_Year Certificate  \
# 0                       the shawshank redemption          1994           a
# 1                                  the godfather          1972           a
# 2                                the dark knight          2008          ua
# 3                         the godfather: part ii          1974           a
# ...

# %%
def movies_you_might_like(title)->dict:
    if title and len(title) >4:
        genres_you_like = (movie_df[series].str.ctains(title,case=False))
        watched_movies=[title filter]
        if watched_movies.empty:
            print{error}
        input_m0vie=watched_movie.iloc[0]
        input_genre=input[genre].split(',')
        other_movies_df[~title_filter].copy()
        other_movies[genre_overlap]=other_movies[Genre]
        lambda x:len(set(x.split(','))& input_genre)
        reccomendations=other_movies[other_movies['genre_overlap']>1]
         reccomendations= reccomendations.sort_values(
             by=['genre_overlap'],
             ascending=[False,False]
         )
        return{movies_you_might_like}: reccomendations[['series_Title','Genre']]
# Out:
#   Cell In[42], line 4
#     watched_movies=[title filter]
#                     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
movies_you_might_like('the godfather')
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/m/mv5bmdfkyt...
# 1    https://m.media-amazon.com/images/m/mv5bm2mynj...
# 2    https://m.media-amazon.com/images/m/mv5bmtmxnt...
# 3    https://m.media-amazon.com/images/m/mv5bmwmwmg...
# 4    https://m.media-amazon.com/images/m/mv5bmwu4n2...
# ..                                                 ...
# 990  https://m.media-amazon.com/images/m/mv5byjrmy2...
# 991  https://m.media-amazon.com/images/m/mv5bmzaynd...
# 992  https://m.media-amazon.com/images/m/mv5bmjawmt...
# 994  https://m.media-amazon.com/images/m/mv5bzjqymg...
# 997  https://m.media-amazon.com/images/m/mv5bm2u3yz...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    the shawshank redemption          1994           a  142 min
# 1               the godfather          1972           a  175 min
# 2             the dark knight          2008          ua  152 min
# ...

# %%
movies_df.dropna(subset=['Genre','Overview'],inplace=True)
def clean(text):
    if isinstance(text):
        return text.lower().strip()
    return text
text_columns=['Genre','Overview']
for col in text_columns:
    movies_df[col] = movies_app[col]y(clean_text)
