# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('company_data.csv')
df
# Out:
#        Order ID  Order Date   Unit Cost   Price  Order Qty  Cost of Sales  \
# 0          7077   9/13/2017   76.094968  304.00          9     684.854710
# 1           117   8/20/2016    7.491753   12.99          4      29.967011
# 2          7018    7/8/2016   10.122338  159.99          9      91.101039
# 3           140   8/11/2018    0.576153   25.69         18      10.370759
# 4           491   7/15/2017  108.508777  304.00          9     976.578991
# ...         ...         ...         ...     ...        ...            ...
# 14995     22348   10/3/2016   16.240455   25.00         12     194.885455
# 14996     22349  10/20/2016   55.387212  999.00         10     553.872121
# 14997     22350   5/20/2017  363.634986  588.00         13    4727.254816
# 14998     22351   11/5/2017  113.237461  279.00         12    1358.849536
# 14999     22352    9/1/2018   10.936943   15.90         20     218.738862
#
#            Sales       Profit   Channel                   Promotion Name  \
# ...

# %%
df=pd.read_csv('company_data.csv')
df['Order Date'] = pd.to_datetime(df['Order Date']).dt.month.astype(str)
import pandas as pd

# Sample DataFrame
# df = pd.DataFrame({'Order Date': [1, 5, 12, 7, 3]})

# Convert numeric month to month name
# df['Order Date'] = pd.to_datetime(df['Order Date'], format='%m').dt.strftime('%B')

# print(df)

# pd.set_option('future.no_silent_downcasting', True)
# df['Order Date'] = df['Order Date'].astype(object)
# df['Order Date'] = df['Order Date'].replace({
    # '1': 'January', '2': 'February', '3': 'March', '4': 'April',
    # '5': 'May', '6': 'June', '7': 'July', '8': 'August',
    # '9': 'September', '10': 'October', '11': 'November', '12': 'December'
# })

df['Order Date']=df['Order Date'].astype(str).str.extract(r'^(\d+)')
df['Order Date']=df['Order Date'].replace({'1':'January',
                                           '2':'February',
                                           '3':'March',
                                           '4':'April',
                                           '5':'May',
                                           '6':'June',
                                           '7':'July',
                                           '8':'August',
                                           '9':'September',
                                           '10':'October',
                                           '11':'November',
                                           '12':'December'
})

order=df.loc[0:10,'Order Date']
sales=df.loc[0:10,'Sales']
profit=df.loc[0:10,'Profit']
Qty=df.loc[0:10,'Order Qty']
fig,axs=plt.subplots(3,1,figsize=(8,10))
axs[0].plot(order,sales,color='blue',markerfacecolor='g',linestyle='--')
axs[0].set(title='order date against',xlabel='Order Date',ylabel='Sales (mkw)')
plt.xticks(rotation=45)
axs[0].grid(True)

axs[1].bar(order,profit)
# ,color='orange',markerfacecolor='r',linestyle='--')
axs[1].set(title='Order date against Profit',xlabel='Order Date',ylabel='Profit (mkw)')
# plt.xticks(rotation=90)

axs[1].grid(True)
axs[2].plot(order,Qty,color='red',markerfacecolor='g',linestyle='--')
axs[2].set(title='Order Date against Order Qty',xlabel='Order Date',ylabel='Order Qty')
# plt.xticks(rotation=45)
axs[2].grid(True)

# %%
count = (df['Country'] == 'China').sum()
print(f'China appeared {count} times')
# Out:
# China appeared 1673 times

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Count occurrences of each country
country_counts = df['Country'].value_counts()

# Extract values for plotting
x = country_counts.index  # Country names
y = country_counts.values  # Frequency counts

# Create a single subplot
fig, ax = plt.subplots(figsize=(8, 6))

# Plot country counts
ax.plot(x, y, color='blue', marker='o', linestyle='--', markerfacecolor='g')
ax.set(title='Country business trend', xlabel='Country', ylabel='Count')

# Fix x-axis labels rotation
ax.set_xticks(range(len(x)))
ax.set_xticklabels(x, rotation=90)

# Enable grid for better visualization
ax.grid(True)

# Show plot
# plt.tight_layout()  # Prevents overlapping labels
plt.show()
# Out:
# C:\Users\Student.DESK-13\AppData\Local\Temp\ipykernel_4408\623072253.py:20: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(x, rotation=90)

# %%
import matplotlib.pyplot as plt

# Create figure and axis for the plot
fig, ax = plt.subplots(figsize=(8, 6))

# Plot country counts
ax.plot(x, y, color='blue', marker='o', linestyle='--', markerfacecolor='g')

# Set titles and labels
ax.set(title='Country Count', xlabel='Country', ylabel='Count')

# Directly set x-axis labels (No `set_xticks()`)
ax.set_xticklabels(x, rotation=45)  # Set country names & rotate

# Enable grid for better visualization
ax.grid(True)

# Show plot
plt.tight_layout()  # Prevent overlapping labels
plt.show()
# Out:
# C:\Users\Student.DESK-13\AppData\Local\Temp\ipykernel_4408\546050029.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(x, rotation=45)  # Set country names & rotate

# %%
import os
