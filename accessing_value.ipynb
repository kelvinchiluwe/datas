# %%
import pandas as pd

# %%
df.columns=[column.replace(' ','-'),for column in df.columns]
df.query("Gender=='Male'",inplace=True)
df
# Out:
#   Cell In[36], line 1
#     df.columns=[column.replace(' ','-'),for column in df.columns]
#                 ^
# SyntaxError: did you forget parentheses around the comprehension target?

# %% [markdown]
# you can access values without using loc like below
# we convert the things which are numeric but somehow they are mixed with strings or Nun to be numeric for easy sorting of accesssing as below

# %%
df['Years of Experience'] = pd.to_numeric(df['Years of Experience'], errors='coerce')
df[df['Years of Experience']>5]
# Out:
#                Timestamp Employer           Location  \
# 0     3/21/2016 12:54:49      NaN        Raleigh, NC
# 1     3/21/2016 12:58:52   Opower  San Francisco, CA
# 3     3/21/2016 12:58:58  Walmart    Bentonville, AR
# 5     3/21/2016 12:59:30      NaN      Palo Alto, CA
# 13    3/21/2016 13:03:03      NaN         Austin, TX
# ...                  ...      ...                ...
# 3694  7/31/2017 13:40:53      NaN                NaN
# 3696    8/8/2017 6:20:54  Startup       New York, NY
# 3700   9/5/2017 16:13:04      NaN                NaN
# 3703  9/20/2017 23:42:12      IBM               Oslo
# 3706  9/28/2017 10:34:48      NaN     Czech Republic
#
#                       Job Title Years at Employer  Years of Experience  \
# 0            Software Developer               NaN                 18.0
# 1              Systems Engineer                 2                 13.0
# 3              Senior Developer                 8                 15.0
# ...

# %%
# df.loc[df['Annual Base Pay']>80000]
df['Annual Base Pay'] = pd.to_numeric(df['Annual Base Pay'], errors='coerce')
df.loc[df['Annual Base Pay'] > 80000]

# df.dropna(subset=['Annual Base Pay']).loc[df['Annual Base Pay'] > 80000]
# Out:
#                 Timestamp            Employer            Location  \
# 0      3/21/2016 12:54:49                 NaN         Raleigh, NC
# 1      3/21/2016 12:58:52              Opower   San Francisco, CA
# 4      3/21/2016 12:59:11  Vertical Knowledge       Cleveland, OH
# 5      3/21/2016 12:59:30                 NaN       Palo Alto, CA
# 6      3/21/2016 13:00:17              NetApp             Waltham
# ...                   ...                 ...                 ...
# 3699   8/31/2017 21:53:57                 NaN  New York, NY (NYC)
# 3700    9/5/2017 16:13:04                 NaN                 NaN
# 3701    9/6/2017 15:26:07                Eaze       San Francisco
# 3703   9/20/2017 23:42:12                 IBM                Oslo
# 3710  10/16/2017 20:34:09             Twitter              Boston
#
#                      Job Title Years at Employer Years of Experience  \
# 0           Software Developer               NaN                  18
# ...

# %%
we use na=False when we want to access the data which contains NaN

# %%
df.loc[df['Gender'].str.contains('Female',na=False)]
# Out:
#                 Timestamp       Employer        Location  \
# 111    3/21/2016 13:13:55            NaN     Raleigh, NC
# 127    3/21/2016 13:14:50      Microsoft     Redmond, WA
# 133    3/21/2016 13:15:38            NaN             NaN
# 157    3/21/2016 13:17:36      Microsoft      London, UK
# 206    3/21/2016 13:22:39       Software             NaN
# ...                   ...            ...             ...
# 3514    4/1/2016 16:45:13            JLL     Chicago, IL
# 3547    5/1/2016 19:03:29     Non profit  Washington, DC
# 3638  12/14/2016 14:32:39  Amazon Lab126    Sunnyvale CA
# 3654    1/11/2017 6:30:31            NaN      Charleston
# 3680    5/7/2017 13:38:23            NaN             NaN
#
#                             Job Title Years at Employer Years of Experience  \
# 111          Lead Front-end Developer               2.5                 4.5
# 127                               SDE                 2                   4
# ...

# %%
import csv
df=pd.read_csv('salaries.csv')
df
# Out:
#                 Timestamp            Employer            Location  \
# 0      3/21/2016 12:54:49                 NaN         Raleigh, NC
# 1      3/21/2016 12:58:52              Opower   San Francisco, CA
# 2      3/21/2016 12:58:57                 NaN        San Diego CA
# 3      3/21/2016 12:58:58             Walmart     Bentonville, AR
# 4      3/21/2016 12:59:11  Vertical Knowledge       Cleveland, OH
# ...                   ...                 ...                 ...
# 3706   9/28/2017 10:34:48                 NaN      Czech Republic
# 3707    10/5/2017 5:09:13                bose             germany
# 3708    10/6/2017 7:39:26                 NaN  Bucharest, Romania
# 3709  10/10/2017 18:48:11                 NaN                 NaN
# 3710  10/16/2017 20:34:09             Twitter              Boston
#
#                  Job Title Years at Employer Years of Experience  \
# 0       Software Developer               NaN                  18
# ...
